# %%
import torch as th
import matplotlib.pyplot as plt

normal = th.distributions.normal.Normal(10, 5)

n = 10000

x = normal.sample(sample_shape=th.Size([n]))
y = normal.sample(sample_shape=th.Size([n]))

plt.scatter(x, y)

plt.show()
